# %%
import random
import json
import pickle #for sterilisation
import numpy as np

import nltk
#lemmatizer is used in stemming words
from nltk.stem import WordNetLemmatizer 
nltk.download('punkt')
nltk.download('wordnet')


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout
from tensorflow.keras.optimizers import SGD
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dagbo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dagbo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
lemmatizer = WordNetLemmatizer()

intents = json.loads(open('intents.json').read())

words = []
classes = []
docs = []
ignore = [',',',','?','.']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize is used in splitting words
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        docs.append((word_list, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
            
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore]
words = sorted(set(words))

print (docs)

classes = sorted(set(classes))


#save to file using pickle to dump
pickle.dump(words, open ('words.pkl', 'wb'))#wb means writing into binariries
pickle.dump(classes, open ('classes.pkl', 'wb'))

#represents the words as numerical values using bag_of_words
train = []
empty_output = [0] * len(classes)

for doc in docs:
    #create an empty list of bag of words
    bag = []
    word_patterns = doc[0]
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    for word in words:
        bag.append(1) if word in word_patterns  else bag.append(0)
    
    output = list(empty_output)
    output[classes.index(doc[1])] = 1
    train.append([bag, output])
    
#shuffling train data   
random.shuffle(train)

train = np.array(train)

training_x = list(train[:, 0])
training_y = list(train[:, 1])

#building the neural network model
model = Sequential()
#adding layers to the model
model.add(Dense(128, input_shape=(len(training_x[0]),), activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(len(training_y[0]), activation = 'softmax'))

sgd = SGD(learning_rate=0.01, decay=1e-6, momentum = 0.9, nesterov = True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics = ['accuracy'])

bot = model.fit(np.array(training_x), np.array(training_y), epochs=200, batch_size = 5, verbose = 1)
model.save('Chatbot_model.h5', bot)
print("Finished...")
# Out:
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['tell', 'me', 'a', 'joke', '?'], 'joke'), (['make', 'me', 'laugh'], 'joke'), (['tell', 'me', 'a', 'science', 'joke'], 'joke'), (['tell', 'me', 'something', 'funny'], 'joke'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Awesome', ',', 'thanks'], 'thanks'), (['Thanks', 'for', 'helping', 'me'], 'thanks'), (['see', 'the', 'doctor'], 'appointment'), (['when', 'is', 'the', 'nurse', 'available'], 'appointment'), (['what', 'dates', 'are', 'availble'], 'appointment'), (['next', 'day'], 'next'), (['tomorrow'], 'next'), (['within', '7', 'days'], '7days'), (['next', 'week'], '7days'), (['within', '14', 'days'], '14days'), (['in', '2', 'weeks'], '14days'), (['next', '2', 'weeks'], '14days')]
# Epoch 1/200
# <ipython-input-36-d25bbbc06747>:50: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   train = np.array(train)
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0745 - accuracy: 0.1613
# Epoch 2/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.0912 - accuracy: 0.1290
# Epoch 3/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0949 - accuracy: 0.2581
# Epoch 4/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0648 - accuracy: 0.2581
# Epoch 5/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0510 - accuracy: 0.3871
# Epoch 6/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0262 - accuracy: 0.1613
# Epoch 7/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0526 - accuracy: 0.2581
# Epoch 8/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0400 - accuracy: 0.3226
# Epoch 9/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0559 - accuracy: 0.2903
# Epoch 10/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9872 - accuracy: 0.2903
# Epoch 11/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0028 - accuracy: 0.2258
# Epoch 12/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0533 - accuracy: 0.2258
# Epoch 13/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9927 - accuracy: 0.2903
# Epoch 14/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9798 - accuracy: 0.2903
# Epoch 15/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9950 - accuracy: 0.2258
# Epoch 16/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9508 - accuracy: 0.3548
# Epoch 17/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0127 - accuracy: 0.2581
# Epoch 18/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0241 - accuracy: 0.3871
# Epoch 19/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0674 - accuracy: 0.2258
# Epoch 20/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9210 - accuracy: 0.4194
# Epoch 21/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9324 - accuracy: 0.2581
# Epoch 22/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9614 - accuracy: 0.3548
# Epoch 23/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9516 - accuracy: 0.3871
# Epoch 24/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9244 - accuracy: 0.3871
# Epoch 25/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9031 - accuracy: 0.4516
# Epoch 26/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9443 - accuracy: 0.3226
# Epoch 27/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9558 - accuracy: 0.3548
# Epoch 28/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9225 - accuracy: 0.2903
# Epoch 29/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9485 - accuracy: 0.4194
# Epoch 30/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9265 - accuracy: 0.4839
# Epoch 31/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8750 - accuracy: 0.3871
# Epoch 32/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9442 - accuracy: 0.3871
# Epoch 33/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8850 - accuracy: 0.3871
# Epoch 34/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8891 - accuracy: 0.5161
# Epoch 35/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8480 - accuracy: 0.3871
# Epoch 36/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9040 - accuracy: 0.3226
# Epoch 37/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8768 - accuracy: 0.4516
# Epoch 38/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8949 - accuracy: 0.3548
# Epoch 39/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7646 - accuracy: 0.5484
# Epoch 40/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8900 - accuracy: 0.3871
# Epoch 41/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7670 - accuracy: 0.5484
# Epoch 42/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.8087 - accuracy: 0.4516
# Epoch 43/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8274 - accuracy: 0.4839
# Epoch 44/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7837 - accuracy: 0.4194
# Epoch 45/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7814 - accuracy: 0.4194
# Epoch 46/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7528 - accuracy: 0.5484
# Epoch 47/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7453 - accuracy: 0.5161
# Epoch 48/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7905 - accuracy: 0.4516
# Epoch 49/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7717 - accuracy: 0.4839
# Epoch 50/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7917 - accuracy: 0.4839
# Epoch 51/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7047 - accuracy: 0.6452
# Epoch 52/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7562 - accuracy: 0.4516
# Epoch 53/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7045 - accuracy: 0.5161
# Epoch 54/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.8131 - accuracy: 0.3548
# Epoch 55/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7149 - accuracy: 0.5484
# Epoch 56/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7324 - accuracy: 0.4839
# Epoch 57/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.6604 - accuracy: 0.5161
# Epoch 58/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7562 - accuracy: 0.4839
# Epoch 59/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6381 - accuracy: 0.6129
# Epoch 60/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6952 - accuracy: 0.4516
# Epoch 61/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7605 - accuracy: 0.3548
# Epoch 62/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6946 - accuracy: 0.4516
# Epoch 63/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6621 - accuracy: 0.4839
# Epoch 64/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6703 - accuracy: 0.4839
# Epoch 65/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6661 - accuracy: 0.5806
# Epoch 66/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5907 - accuracy: 0.5806
# Epoch 67/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6756 - accuracy: 0.4516
# Epoch 68/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5511 - accuracy: 0.4839
# Epoch 69/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5992 - accuracy: 0.5161
# Epoch 70/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5559 - accuracy: 0.6452
# Epoch 71/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6078 - accuracy: 0.5484
# Epoch 72/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.6344 - accuracy: 0.5161
# Epoch 73/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.6487 - accuracy: 0.5484
# Epoch 74/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6084 - accuracy: 0.5806
# Epoch 75/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5375 - accuracy: 0.5161
# Epoch 76/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.5354 - accuracy: 0.6129
# Epoch 77/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4691 - accuracy: 0.6452
# Epoch 78/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5600 - accuracy: 0.4194
# Epoch 79/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5106 - accuracy: 0.6129
# Epoch 80/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5410 - accuracy: 0.5484
# Epoch 81/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4302 - accuracy: 0.6452
# Epoch 82/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6118 - accuracy: 0.4839
# Epoch 83/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4484 - accuracy: 0.5484
# Epoch 84/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4678 - accuracy: 0.6774
# Epoch 85/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5171 - accuracy: 0.6129
# Epoch 86/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4646 - accuracy: 0.5806
# Epoch 87/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4517 - accuracy: 0.4516
# Epoch 88/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4845 - accuracy: 0.5806
# Epoch 89/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5135 - accuracy: 0.4839
# Epoch 90/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4485 - accuracy: 0.5806
# Epoch 91/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4452 - accuracy: 0.6774
# Epoch 92/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4166 - accuracy: 0.5806
# Epoch 93/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5342 - accuracy: 0.5161
# Epoch 94/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3384 - accuracy: 0.7097
# Epoch 95/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4471 - accuracy: 0.6129
# Epoch 96/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4799 - accuracy: 0.5806
# Epoch 97/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3793 - accuracy: 0.5161
# Epoch 98/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4107 - accuracy: 0.6129
# Epoch 99/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3018 - accuracy: 0.7097
# Epoch 100/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3522 - accuracy: 0.6774
# Epoch 101/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2523 - accuracy: 0.7097
# Epoch 102/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3117 - accuracy: 0.7097
# Epoch 103/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3178 - accuracy: 0.6452
# Epoch 104/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3001 - accuracy: 0.6774
# Epoch 105/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2658 - accuracy: 0.6129
# Epoch 106/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2612 - accuracy: 0.6774
# Epoch 107/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3690 - accuracy: 0.7097
# Epoch 108/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2557 - accuracy: 0.6774
# Epoch 109/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2743 - accuracy: 0.6452
# Epoch 110/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1455 - accuracy: 0.7742
# Epoch 111/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1857 - accuracy: 0.7742
# Epoch 112/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3623 - accuracy: 0.6129
# Epoch 113/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2742 - accuracy: 0.7097
# Epoch 114/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3468 - accuracy: 0.7097
# Epoch 115/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1377 - accuracy: 0.7419
# Epoch 116/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2923 - accuracy: 0.6129
# Epoch 117/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1603 - accuracy: 0.7419
# Epoch 118/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2032 - accuracy: 0.7097
# Epoch 119/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2440 - accuracy: 0.6452
# Epoch 120/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1887 - accuracy: 0.6774
# Epoch 121/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1571 - accuracy: 0.7097
# Epoch 122/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2157 - accuracy: 0.6452
# Epoch 123/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1987 - accuracy: 0.6774
# Epoch 124/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2479 - accuracy: 0.6129
# Epoch 125/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2070 - accuracy: 0.7097
# Epoch 126/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2420 - accuracy: 0.7097
# Epoch 127/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1509 - accuracy: 0.6129
# Epoch 128/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3357 - accuracy: 0.6129
# Epoch 129/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1850 - accuracy: 0.6774
# Epoch 130/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1006 - accuracy: 0.7419
# Epoch 131/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0957 - accuracy: 0.6774
# Epoch 132/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0915 - accuracy: 0.6452
# Epoch 133/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2761 - accuracy: 0.5806
# Epoch 134/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1365 - accuracy: 0.6774
# Epoch 135/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0618 - accuracy: 0.6774
# Epoch 136/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1418 - accuracy: 0.6452
# Epoch 137/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1204 - accuracy: 0.7419
# Epoch 138/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9939 - accuracy: 0.7097
# Epoch 139/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0540 - accuracy: 0.7742
# Epoch 140/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1938 - accuracy: 0.6774
# Epoch 141/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0843 - accuracy: 0.7097
# Epoch 142/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1031 - accuracy: 0.6452
# Epoch 143/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9851 - accuracy: 0.7419
# Epoch 144/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9583 - accuracy: 0.7742
# Epoch 145/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0581 - accuracy: 0.8065
# Epoch 146/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0828 - accuracy: 0.7419
# Epoch 147/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0946 - accuracy: 0.7742
# Epoch 148/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0180 - accuracy: 0.7742
# Epoch 149/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9565 - accuracy: 0.7419
# Epoch 150/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9991 - accuracy: 0.6129
# Epoch 151/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9979 - accuracy: 0.6774
# Epoch 152/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1376 - accuracy: 0.7419
# Epoch 153/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0189 - accuracy: 0.7742
# Epoch 154/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9575 - accuracy: 0.7419
# Epoch 155/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1099 - accuracy: 0.7419
# Epoch 156/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9242 - accuracy: 0.7419
# Epoch 157/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9662 - accuracy: 0.7419
# Epoch 158/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8849 - accuracy: 0.7742
# Epoch 159/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9689 - accuracy: 0.7419
# Epoch 160/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9298 - accuracy: 0.8065
# Epoch 161/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8250 - accuracy: 0.8065
# Epoch 162/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0044 - accuracy: 0.7097
# Epoch 163/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9015 - accuracy: 0.8065
# Epoch 164/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0308 - accuracy: 0.6774
# Epoch 165/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8548 - accuracy: 0.8065
# Epoch 166/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9129 - accuracy: 0.7742
# Epoch 167/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9123 - accuracy: 0.7097
# Epoch 168/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8007 - accuracy: 0.8387
# Epoch 169/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8620 - accuracy: 0.8387
# Epoch 170/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9532 - accuracy: 0.7742
# Epoch 171/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7504 - accuracy: 0.7742
# Epoch 172/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8456 - accuracy: 0.8065
# Epoch 173/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8951 - accuracy: 0.7742
# Epoch 174/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8158 - accuracy: 0.8065
# Epoch 175/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6850 - accuracy: 0.8065
# Epoch 176/200
# 7/7 [==============================] - 0s 1ms/step - loss: 0.9489 - accuracy: 0.6774
# Epoch 177/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9144 - accuracy: 0.7419
# Epoch 178/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8833 - accuracy: 0.7742
# Epoch 179/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7563 - accuracy: 0.8710
# Epoch 180/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8412 - accuracy: 0.7419
# Epoch 181/200
# 7/7 [==============================] - 0s 1ms/step - loss: 0.7159 - accuracy: 0.8065
# Epoch 182/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9309 - accuracy: 0.7742
# Epoch 183/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8165 - accuracy: 0.8065
# Epoch 184/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8787 - accuracy: 0.8065
# Epoch 185/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7590 - accuracy: 0.8065
# Epoch 186/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9097 - accuracy: 0.8065
# Epoch 187/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8037 - accuracy: 0.8065
# Epoch 188/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6917 - accuracy: 0.8065
# Epoch 189/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8410 - accuracy: 0.7742
# Epoch 190/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9234 - accuracy: 0.7742
# Epoch 191/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7421 - accuracy: 0.7097
# Epoch 192/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7961 - accuracy: 0.7742
# Epoch 193/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7498 - accuracy: 0.7742
# Epoch 194/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8205 - accuracy: 0.7419
# Epoch 195/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7604 - accuracy: 0.8065
# Epoch 196/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7488 - accuracy: 0.8710
# Epoch 197/200
# 7/7 [==============================] - 0s 1ms/step - loss: 0.8622 - accuracy: 0.7742
# Epoch 198/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6703 - accuracy: 0.8387
# Epoch 199/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6783 - accuracy: 0.9355
# Epoch 200/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7615 - accuracy: 0.7742
# Finished...
